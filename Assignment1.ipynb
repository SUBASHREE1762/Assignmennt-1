# %% [markdown]
# <a href="https://colab.research.google.com/github/SUBASHREE1762/Assignment-1/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AI ASSIGNMENT-1
#Task 1:Download the dataset
#Task 2: Load the dataset
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/House Price India.csv')
print(df.describe())
plt.hist(df['Price'])
plt.show()
plt.boxplot(df['Price'])
plt.show()
df['Price'].value_counts().plot(kind='bar')
plt.show()

# %%
#Task 3: Univariate Analysis
#scatterplot year vs price
import pandas as pd
import seaborn as sns
data = pd.read_csv('/content/House Price India.csv')
sns.scatterplot(x='Built Year', y='Price', data=data)
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
#Task 3: Bi - Variate Analysis
#lineplot year vs price
import pandas as pd
import seaborn as sns
data = pd.read_csv('/content/House Price India.csv')
sns.lineplot(x='Built Year', y='Price', data=data)
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
#barplot year vs price
sns.barplot(x='Built Year', y='Price', data=data)
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
#histplot year 
sns.histplot(x='Built Year', data=data)

# %%
#boxplot year vs price
sns.boxplot(x='Built Year', y='Price', data=data)
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
#Task 3: Multi-Variate Analysis
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
data = pd.read_csv("/content/House Price India.csv")
data = data.dropna()
corr_matrix = data.corr()
print(corr_matrix)
corr_coef, p_value = pearsonr(data['Built Year'], data['Price'])
print("Correlation coefficient:", corr_coef)
print("P-value:", p_value)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_components = pca.fit_transform(data)
print(pca.explained_variance_ratio_)
import matplotlib.pyplot as plt

plt.scatter(principal_components[:,0], principal_components[:,1])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.show()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
#Task 4: Descriptive statistics
import pandas as pd
csv_file_path = '/content/House Price India.csv'
chunk_size = 10000
count = 0
mean = 0
M2 = 0
for chunk in pd.read_csv(csv_file_path, chunksize=chunk_size):
    x = chunk['Price']
    n = len(x)
    delta = x - mean
    mean += delta.sum() / n
    M2 += (delta * (x - mean)).sum()
    count += n
variance = M2 / (count - 1)
stddev = variance ** 0.5
mean = mean
print(f"Mean: {mean:.2f}")
print(f"Standard deviation: {stddev:.2f}")
# Out:
# Mean: 528068.73
# Standard deviation: 367458.19

# %%
#Task 5: Handling the Missing values.
import pandas as pd
df = pd.read_csv('/content/House Price India.csv')
missing_values = df.isnull().sum()
print(missing_values)
df.fillna(df.mean(), inplace=True)
df.to_csv('/content/missing.csv', index=False)
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...
